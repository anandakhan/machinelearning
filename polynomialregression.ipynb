# %%
from google.colab import files
files .upload()
# Out:
#      <input type="file" id="files-d2061d9b-efc9-4295-a7f7-78d48f32cab6" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d2061d9b-efc9-4295-a7f7-78d48f32cab6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving data.csv to data.csv
# {'data.csv': b'sno,Temperature,Pressure\r\n1,0,0.0002\r\n2,20,0.0012\r\n3,40,0.006\r\n4,60,0.03\r\n5,80,0.09\r\n6,100,0.27\r\n'}

# %%
# Importing the libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# Importing the dataset
datas = pd.read_csv('data.csv')
datas
# Out:
#    sno  Temperature  Pressure
# 0    1            0    0.0002
# 1    2           20    0.0012
# 2    3           40    0.0060
# 3    4           60    0.0300
# 4    5           80    0.0900
# 5    6          100    0.2700

# %%
X = datas.iloc[:, 1:2].values
y = datas.iloc[:, 2].values
#print(X)
print(y)
# Out:
# [2.0e-04 1.2e-03 6.0e-03 3.0e-02 9.0e-02 2.7e-01]

# %%
# Fitting Linear Regression to the dataset
from sklearn.linear_model import LinearRegression
lin = LinearRegression()

lin.fit(X, y)
# Out:
# LinearRegression()

# %%
# Fitting Polynomial Regression to the dataset
from sklearn.preprocessing import PolynomialFeatures

poly = PolynomialFeatures(degree = 8)
X_poly = poly.fit_transform(X)

poly.fit(X_poly, y)
lin2 = LinearRegression()
lin2.fit(X_poly, y)
# Out:
# LinearRegression()

# %%
# Visualising the Linear Regression results
plt.scatter(X, y, color = 'skyblue')

plt.plot(X, lin.predict(X), color = 'red')
plt.title('Linear Regression')
plt.xlabel('Temperature')
plt.ylabel('Pressure')

plt.show()

# %%
# Visualising the Linear Regression results
plt.scatter(X, y, color = 'skyblue')

plt.plot(X, lin2.predict(X_poly), color = 'red')
plt.title('Linear Regression')
plt.xlabel('Temperature')
plt.ylabel('Pressure')

plt.show()

# %%
# Predicting a new result with Linear Regression after converting predict variable to 2D array
pred = 107.0
predarray = np.array([[pred]])
lin.predict(predarray)
# Out:
# array([0.19972733])

# %%
# Predicting a new result with Polynomial Regression after converting predict variable to 2D array
pred2 = 105.0
pred2array = np.array([[pred2]])
lin2.predict(poly.fit_transform(pred2array))
# Out:
# array([0.42247697])
