# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-5aecfc16-34f3-42cf-9a98-1854aac100f0" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5aecfc16-34f3-42cf-9a98-1854aac100f0">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving winequality-red.csv to winequality-red.csv
# ...

# %%
import pandas as pd
import numpy as np
import graphviz
from sklearn import tree
import matplotlib.pyplot as plt
import pydotplus
from sklearn.tree import DecisionTreeClassifier, export_graphviz
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, confusion_matrix
from IPython.display import Image

# %%
data = pd.read_csv('winequality-red.csv')
data.head(5)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
data.isna().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
data.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
X = data.drop(columns = ['quality'])
y = data['quality']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state= 0)

# %%
X_train.shape
# Out:
# (1199, 11)

# %%
X_test.shape
# Out:
# (400, 11)

# %%
y_train.shape
# Out:
# (1199,)

# %%
y_test.shape
# Out:
# (400,)

# %%
clf = DecisionTreeClassifier()
clf.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
feature_name = list(X.columns)
#feature_name
class_name = list(y_train.unique())
class_name
# Out:
# [5, 6, 7, 4, 3, 8]

# %%
dot_data = export_graphviz(clf, feature_names = feature_name, rounded = True, filled = True)
graph = pydotplus.graph_from_dot_data(dot_data)
graph.write_png('dtree.png')
Image(graph.create_png())
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
clf.score(X_train,y_train)
# Out:
# 1.0

# %%
y_pred = clf.predict(X_test)
clf.score(X_test, y_test)
# Out:
# 0.625

# %%
scalar = StandardScaler()
x_transform = scalar.fit_transform(X)

# %%
x_train, x_test, y_train, y_test = train_test_split(x_transform, y, test_size = 0.3, random_state = 355)

# %%
pca = PCA()
principalcomponents = pca.fit_transform(x_transform)
plt.figure()
plt.plot(np.cumsum(pca.explained_variance_ratio_), color = 'r')
plt.xlabel('Number of components')
plt.ylabel('Variaance')
plt.title('Explained Variance')
plt.show()

# %%
pca = PCA(n_components= 8)
data1 = pca.fit_transform(x_transform)
principal_components = pd.DataFrame(data1, columns = ['PC-1','PC-2','PC-3','PC-4','PC-5','PC-6','PC-7','PC-8'])
principal_components
# Out:
#           PC-1      PC-2      PC-3      PC-4      PC-5      PC-6      PC-7  \
# 0    -1.619530  0.450950 -1.774454  0.043740  0.067014 -0.913921 -0.161043
# 1    -0.799170  1.856553 -0.911690  0.548066 -0.018392  0.929714 -1.009829
# 2    -0.748479  0.882039 -1.171394  0.411021 -0.043531  0.401473 -0.539553
# 3     2.357673 -0.269976  0.243489 -0.928450 -1.499149 -0.131017  0.344290
# 4    -1.619530  0.450950 -1.774454  0.043740  0.067014 -0.913921 -0.161043
# ...        ...       ...       ...       ...       ...       ...       ...
# 1594 -2.150500  0.814286  0.617063  0.407687 -0.240936  0.054835  0.170812
# 1595 -2.214496  0.893101  1.807402  0.414003  0.119592 -0.674711 -0.607970
# 1596 -1.456129  0.311746  1.124239  0.491877  0.193716 -0.506410 -0.231082
# 1597 -2.270518  0.979791  0.627965  0.639770  0.067735 -0.860408 -0.321487
# 1598 -0.426975 -0.536690  1.628955 -0.391716  0.450482 -0.496154  1.189132
#
#           PC-8
# 0    -0.282258
# 1     0.762587
# 2     0.597946
# ...

# %%
X_train,X_test, y_train,y_test = train_test_split(principal_components, y, test_size= 0.3, random_state= 355)
clf = DecisionTreeClassifier()
clf.fit(X_train, y_train)
clf.score(X_test, y_test)
# Out:
# 0.59375

# %%
grid_param = {'criterion':['gini','entropy'],'max_depth' : (2,32,1), 'min_samples_leaf': range(1, 10 ,1),'min_samples_split': range(2,10,1),'splitter': ['best','random']}

# %%
grid_search = GridSearchCV(estimator= clf, param_grid = grid_param, cv = 5 ,n_jobs = -1)

# %%
grid_search.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(), n_jobs=-1,
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': (2, 32, 1),
#                          'min_samples_leaf': range(1, 10),
#                          'min_samples_split': range(2, 10),
#                          'splitter': ['best', 'random']})

# %%
best_parameters = grid_search.best_params_
print(best_parameters)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-49-68756e0ba1dc> in <module>()
# ----> 1 best_parameters = grid_search.best_params_
#       2 print(best_parameters)
#
# AttributeError: 'GridSearchCV' object has no attribute 'best_params_'

# %%
grid_search.best_score_
# Out:
# 0.5978299167200513

# %%
clf = DecisionTreeClassifier(criterion= 'entropy', max_depth= 30, min_samples_leaf= 1, min_samples_split= 3, splitter= 'best')
clf.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=30, min_samples_split=3)

# %%
clf.score(X_test,y_test)
# Out:
# 0.5145833333333333

# %%
feature_name = list(X.columns)
class_name = list(y_train.unique())
dot_data = export_graphviz(clf, rounded =True, filled =True)
graph = pydotplus.graph_from_dot_data(dot_data)
Image(graph.create_png())
# Out:
# Output hidden; open in https://colab.research.google.com to view.
